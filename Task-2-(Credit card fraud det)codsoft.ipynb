# %%
import numpy as np
import pandas as pd
import sklearn

# %%
fraud=pd.read_csv('creditcard.csv')

# %%
fraud
# Out:
#             time         v1         v2        v3        v4        v5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               v6        v7        v8        v9  ...       v21       v22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              v23       v24       v25       v26       v27       v28  amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [283726 rows x 31 columns]

# %%
fraud.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376
# 284798 -1.014307  0.427126  0.121340 -0.285670  ...  0.099936  0.337120
# 284799  5.519980 -1.518185  2.080825  1.159498  ...  0.103302  0.654850
# 284800 -0.726571  0.017050 -0.118228  0.435402  ... -0.268048 -0.717211
# 284801 -0.235973  0.812722  0.115093 -0.204064  ... -0.314205 -0.808520
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284797  0.279598  0.371441 -0.559238  0.113144  0.131507  0.081265    5.49
# 284798  0.251791  0.057688 -1.508368  0.144023  0.181205  0.215243   24.05
# 284799 -0.348929  0.745323  0.704545 -0.127579  0.454379  0.130308   79.99
# 284800  0.297930 -0.359769 -0.315610  0.201114 -0.080826 -0.075071    2.68
# 284801  0.050343  0.102800 -0.435870  0.124079  0.217940  0.068803    2.69
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284797      0
# 284798      0
# 284799      0
# 284800      0
# 284801      0
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [10 rows x 31 columns]

# %%
fraud.head(10)
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          v8        v9  ...       v21       v22       v23       v24       v25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         v26       v27       v28  amount  class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
fraud.shape
# Out:
# (284807, 31)

# %%
fraud.size
# Out:
# 8829017

# %%
fraud.columns=fraud.columns.str.lower()
fraud.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
fraud.isna().sum()
# Out:
# time      0
# v1        0
# v2        0
# v3        0
# v4        0
# v5        0
# v6        0
# v7        0
# v8        0
# v9        0
# v10       0
# v11       0
# v12       0
# v13       0
# v14       0
# v15       0
# v16       0
# v17       0
# v18       0
# v19       0
# v20       0
# v21       0
# v22       0
# v23       0
# v24       0
# v25       0
# v26       0
# v27       0
# v28       0
# amount    0
# class     0
# dtype: int64

# %%
fraud.columns
# Out:
# Index(['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
#        'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
#        'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
#        'class'],
#       dtype='object')

# %%
fraud[fraud.duplicated(subset=['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
       'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
       'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
       'class'],keep=False)]
# Out:
#             time        v1        v2        v3        v4        v5        v6  \
# 32          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 34          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 112         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284190  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284192  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
#               v7        v8        v9  ...       v21       v22       v23  \
# 32      0.711206  0.176066 -0.286717  ...  0.046949  0.208105 -0.185548
# 33      0.711206  0.176066 -0.286717  ...  0.046949  0.208105 -0.185548
# 34      0.693039  0.179742 -0.285642  ...  0.049526  0.206537 -0.187108
# 35      0.693039  0.179742 -0.285642  ...  0.049526  0.206537 -0.187108
# 112    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# ...          ...       ...       ...  ...       ...       ...       ...
# 283485 -0.282535  0.880654  0.052808  ...  0.284205  0.949659 -0.216949
# 284190 -0.667233  2.309700 -1.639306  ...  0.391483  0.266536 -0.079853
# 284191 -0.667233  2.309700 -1.639306  ...  0.391483  0.266536 -0.079853
# 284192 -0.745886  2.325616 -1.634651  ...  0.402639  0.259746 -0.086606
# 284193 -0.745886  2.325616 -1.634651  ...  0.402639  0.259746 -0.086606
#
#              v24       v25       v26       v27       v28  amount  class
# 32      0.001031  0.098816 -0.552904 -0.073288  0.023307    6.14      0
# 33      0.001031  0.098816 -0.552904 -0.073288  0.023307    6.14      0
# 34      0.000753  0.098117 -0.553471 -0.078306  0.025427    1.77      0
# 35      0.000753  0.098117 -0.553471 -0.078306  0.025427    1.77      0
# 112    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 283485  0.083250  0.044944  0.639933  0.219432  0.116772   11.93      0
# 284190 -0.096395  0.086719 -0.451128 -1.183743 -0.222200   55.66      0
# 284191 -0.096395  0.086719 -0.451128 -1.183743 -0.222200   55.66      0
# 284192 -0.097597  0.083693 -0.453584 -1.205466 -0.213020   36.74      0
# 284193 -0.097597  0.083693 -0.453584 -1.205466 -0.213020   36.74      0
#
# [1854 rows x 31 columns]

# %%
fraud.drop_duplicates(subset=['time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9', 'v10',
       'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18', 'v19', 'v20',
       'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27', 'v28', 'amount',
       'class'],keep='first',inplace=True)

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283726 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    283726 non-null  float64
#  1   v1      283726 non-null  float64
#  2   v2      283726 non-null  float64
#  3   v3      283726 non-null  float64
#  4   v4      283726 non-null  float64
#  5   v5      283726 non-null  float64
#  6   v6      283726 non-null  float64
#  7   v7      283726 non-null  float64
#  8   v8      283726 non-null  float64
#  9   v9      283726 non-null  float64
#  10  v10     283726 non-null  float64
#  11  v11     283726 non-null  float64
#  12  v12     283726 non-null  float64
#  13  v13     283726 non-null  float64
#  14  v14     283726 non-null  float64
#  15  v15     283726 non-null  float64
#  16  v16     283726 non-null  float64
#  17  v17     283726 non-null  float64
#  18  v18     283726 non-null  float64
#  19  v19     283726 non-null  float64
#  20  v20     283726 non-null  float64
#  21  v21     283726 non-null  float64
#  22  v22     283726 non-null  float64
#  23  v23     283726 non-null  float64
#  24  v24     283726 non-null  float64
#  25  v25     283726 non-null  float64
#  26  v26     283726 non-null  float64
#  27  v27     283726 non-null  float64
#  28  v28     283726 non-null  float64
#  29  amount  283726 non-null  float64
#  30  class   283726 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 69.3 MB

# %%
fraud.describe()
# Out:
#                 time             v1             v2             v3  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean    94811.077600       0.005917      -0.004135       0.001613
# std     47481.047891       1.948026       1.646703       1.508682
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54204.750000      -0.915951      -0.600321      -0.889682
# 50%     84692.500000       0.020384       0.063949       0.179963
# 75%    139298.000000       1.316068       0.800283       1.026960
# max    172792.000000       2.454930      22.057729       9.382558
#
#                   v4             v5             v6             v7  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean       -0.002966       0.001828      -0.001139       0.001801
# std         1.414184       1.377008       1.331931       1.227664
# min        -5.683171    -113.743307     -26.160506     -43.557242
# 25%        -0.850134      -0.689830      -0.769031      -0.552509
# 50%        -0.022248      -0.053468      -0.275168       0.040859
# 75%         0.739647       0.612218       0.396792       0.570474
# max        16.875344      34.801666      73.301626     120.589494
#
#                   v8             v9  ...            v21            v22  \
# count  283726.000000  283726.000000  ...  283726.000000  283726.000000
# mean       -0.000854      -0.001596  ...      -0.000371      -0.000015
# std         1.179054       1.095492  ...       0.723909       0.724550
# min       -73.216718     -13.434066  ...     -34.830382     -10.933144
# 25%        -0.208828      -0.644221  ...      -0.228305      -0.542700
# 50%         0.021898      -0.052596  ...      -0.029441       0.006675
# 75%         0.325704       0.595977  ...       0.186194       0.528245
# max        20.007208      15.594995  ...      27.202839      10.503090
#
#                  v23            v24            v25            v26  \
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.000198       0.000214      -0.000232       0.000149
# std         0.623702       0.605627       0.521220       0.482053
# min       -44.807735      -2.836627     -10.295397      -2.604551
# 25%        -0.161703      -0.354453      -0.317485      -0.326763
# 50%        -0.011159       0.041016       0.016278      -0.052172
# 75%         0.147748       0.439738       0.350667       0.240261
# max        22.528412       4.584549       7.519589       3.517346
#
#                  v27            v28         amount          class
# count  283726.000000  283726.000000  283726.000000  283726.000000
# mean        0.001763       0.000547      88.472687       0.001667
# std         0.395744       0.328027     250.399437       0.040796
# min       -22.565679     -15.430084       0.000000       0.000000
# 25%        -0.070641      -0.052818       5.600000       0.000000
# 50%         0.001479       0.011288      22.000000       0.000000
# 75%         0.091208       0.078276      77.510000       0.000000
# max        31.612198      33.847808   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=fraud,x='class',color = "green")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
fraud['class'].value_counts().to_frame()
# Out:
#     class
# 0  283253
# 1     473

# %%
from sklearn.utils import resample

# %%
fraud_majority=fraud[fraud['class']==0]
fraud_minority=fraud[fraud['class']==1]

# %%
fraud_majority_downsample=resample(fraud_majority,n_samples=473,replace=False,random_state=42)

# %%
fraud_df=pd.concat([fraud_majority_downsample,fraud_minority])

# %%
fraud_df['class'].value_counts().to_frame()
# Out:
#    class
# 0    473
# 1    473

# %%
plt.figure(figsize=(20,8))
sns.countplot(data=fraud_df,x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
fraud_df.corr()
# Out:
#             time        v1        v2        v3        v4        v5        v6  \
# time    1.000000  0.260808 -0.247373  0.180673 -0.245011  0.308935  0.163260
# v1      0.260808  1.000000 -0.781145  0.871437 -0.599812  0.859462  0.365009
# v2     -0.247373 -0.781145  1.000000 -0.846292  0.671447 -0.782957 -0.365287
# v3      0.180673  0.871437 -0.846292  1.000000 -0.757869  0.846066  0.495779
# v4     -0.245011 -0.599812  0.671447 -0.757869  1.000000 -0.562285 -0.440084
# v5      0.308935  0.859462 -0.782957  0.846066 -0.562285  1.000000  0.305056
# v6      0.163260  0.365009 -0.365287  0.495779 -0.440084  0.305056  1.000000
# v7      0.243830  0.867281 -0.825480  0.883227 -0.710487  0.834658  0.357900
# v8     -0.198337 -0.227559  0.143313 -0.289173  0.139941 -0.316985 -0.549485
# v9      0.193129  0.636138 -0.680223  0.748648 -0.785856  0.635433  0.366570
# v10     0.247449  0.709357 -0.749891  0.837951 -0.780450  0.734893  0.447308
# v11    -0.337521 -0.519282  0.615690 -0.718381  0.793427 -0.516595 -0.525924
# v12     0.294417  0.587462 -0.665572  0.755900 -0.826851  0.605279  0.514190
# v13    -0.098634 -0.078503  0.069889 -0.084920  0.047856 -0.141727 -0.056940
# v14     0.200249  0.435103 -0.564927  0.658006 -0.787099  0.423741  0.576426
# v15    -0.171611  0.089380 -0.159574  0.126405 -0.118154  0.065681 -0.089686
# v16     0.263405  0.629485 -0.617573  0.722283 -0.713595  0.688359  0.465467
# v17     0.266780  0.672300 -0.637444  0.732996 -0.697200  0.745019  0.440919
# v18     0.284174  0.676397 -0.616075  0.697562 -0.631927  0.738033  0.375605
# v19    -0.112061 -0.327219  0.232067 -0.325761  0.312904 -0.419005 -0.213286
# v20    -0.043545 -0.348072  0.335795 -0.390555  0.301128 -0.338418 -0.042318
# v21    -0.055685  0.109783 -0.101683  0.072457 -0.049573  0.085628 -0.198321
# v22     0.094389 -0.091185  0.103932 -0.104319  0.174882 -0.123645  0.164002
# v23     0.076133  0.004507  0.087695  0.005148  0.016402 -0.066063  0.256284
# v24    -0.000043 -0.074499 -0.003433  0.029983 -0.102288 -0.124094 -0.017781
# v25    -0.197178 -0.107965  0.135224 -0.108728 -0.011845 -0.110947 -0.157928
# v26    -0.048243  0.053400 -0.006763 -0.032016  0.127344  0.053724 -0.015149
# v27    -0.135243  0.104882 -0.094864  0.002408  0.053355  0.101633 -0.224261
# v28     0.018830  0.151901  0.024285  0.090332 -0.085654  0.135551 -0.070580
# amount  0.025681 -0.036482 -0.267597 -0.020110 -0.011463 -0.108903  0.223830
# class  -0.175596 -0.414065  0.473475 -0.557682  0.696688 -0.361055 -0.435321
#
#               v7        v8        v9  ...       v21       v22       v23  \
# time    0.243830 -0.198337  0.193129  ... -0.055685  0.094389  0.076133
# v1      0.867281 -0.227559  0.636138  ...  0.109783 -0.091185  0.004507
# v2     -0.825480  0.143313 -0.680223  ... -0.101683  0.103932  0.087695
# v3      0.883227 -0.289173  0.748648  ...  0.072457 -0.104319  0.005148
# v4     -0.710487  0.139941 -0.785856  ... -0.049573  0.174882  0.016402
# v5      0.834658 -0.316985  0.635433  ...  0.085628 -0.123645 -0.066063
# v6      0.357900 -0.549485  0.366570  ... -0.198321  0.164002  0.256284
# v7      1.000000 -0.055355  0.769612  ...  0.200895 -0.252839 -0.023010
# v8     -0.055355  1.000000 -0.096914  ...  0.353670 -0.326261 -0.305667
# v9      0.769612 -0.096914  1.000000  ...  0.172436 -0.270597 -0.055213
# v10     0.863307 -0.107843  0.847598  ...  0.119918 -0.272723 -0.036118
# v11    -0.644811  0.243510 -0.706826  ...  0.124800  0.084333 -0.063987
# v12     0.730027 -0.212030  0.763484  ... -0.077895 -0.168031  0.013409
# v13    -0.048931  0.222737 -0.032478  ...  0.119046 -0.072490 -0.040284
# v14     0.550751 -0.272427  0.683165  ... -0.209483 -0.014871  0.049358
# v15     0.155829  0.161949  0.111593  ...  0.169760 -0.069519 -0.057163
# v16     0.754584 -0.262562  0.730675  ... -0.125718 -0.197103  0.033148
# v17     0.784225 -0.291437  0.754526  ... -0.095599 -0.186917  0.031498
# v18     0.769165 -0.264643  0.701532  ... -0.057921 -0.181188  0.043847
# v19    -0.374353  0.233645 -0.353389  ...  0.149716  0.170051  0.001351
# v20    -0.421984 -0.166354 -0.372288  ... -0.491517  0.366401  0.198792
# v21     0.200895  0.353670  0.172436  ...  1.000000 -0.613447 -0.135247
# v22    -0.252839 -0.326261 -0.270597  ... -0.613447  1.000000  0.205551
# v23    -0.023010 -0.305667 -0.055213  ... -0.135247  0.205551  1.000000
# v24    -0.039487  0.032922  0.038377  ...  0.001206  0.005555 -0.008876
# v25     0.045521  0.293254 -0.011200  ...  0.139638 -0.261716  0.089703
# v26     0.011935  0.017517 -0.141642  ...  0.016016  0.042837  0.021753
# v27     0.154534  0.382396  0.054325  ...  0.376235 -0.346207 -0.222593
# v28     0.131971  0.067638  0.125616  ...  0.224963 -0.183025 -0.021893
# amount  0.139892 -0.010708  0.025885  ...  0.061911 -0.052337 -0.168728
# class  -0.471417  0.119414 -0.552502  ...  0.106149  0.098741 -0.049263
#
#              v24       v25       v26       v27       v28    amount     class
# time   -0.000043 -0.197178 -0.048243 -0.135243  0.018830  0.025681 -0.175596
# v1     -0.074499 -0.107965  0.053400  0.104882  0.151901 -0.036482 -0.414065
# v2     -0.003433  0.135224 -0.006763 -0.094864  0.024285 -0.267597  0.473475
# v3      0.029983 -0.108728 -0.032016  0.002408  0.090332 -0.020110 -0.557682
# v4     -0.102288 -0.011845  0.127344  0.053355 -0.085654 -0.011463  0.696688
# v5     -0.124094 -0.110947  0.053724  0.101633  0.135551 -0.108903 -0.361055
# v6     -0.017781 -0.157928 -0.015149 -0.224261 -0.070580  0.223830 -0.435321
# v7     -0.039487  0.045521  0.011935  0.154534  0.131971  0.139892 -0.471417
# v8      0.032922  0.293254  0.017517  0.382396  0.067638 -0.010708  0.119414
# v9      0.038377 -0.011200 -0.141642  0.054325  0.125616  0.025885 -0.552502
# v10     0.026739  0.014741 -0.045669  0.053334  0.108011  0.010760 -0.629054
# v11    -0.124906  0.026155  0.141513  0.219707  0.033509 -0.029746  0.689637
# v12     0.069073  0.036544 -0.098228 -0.086922 -0.005742  0.032602 -0.678060
# v13     0.019230  0.003893  0.029620  0.064649 -0.075814  0.023960 -0.061887
# v14     0.162668 -0.073432 -0.148970 -0.234226 -0.109102  0.063879 -0.744855
# v15     0.018579 -0.018234  0.042699  0.134466  0.072430  0.037798 -0.033270
# v16    -0.039020  0.057857 -0.058362 -0.064572  0.012076 -0.010117 -0.584728
# v17    -0.062238  0.033629 -0.023347 -0.045278  0.048309 -0.003082 -0.547153
# v18    -0.093075  0.046731  0.002716  0.006223  0.078432  0.006363 -0.454571
# v19     0.122097 -0.158233  0.056313  0.059385 -0.067607  0.054672  0.262592
# v20    -0.040398  0.037698  0.048729 -0.124210  0.086942  0.242500  0.183601
# v21     0.001206  0.139638  0.016016  0.376235  0.224963  0.061911  0.106149
# v22     0.005555 -0.261716  0.042837 -0.346207 -0.183025 -0.052337  0.098741
# v23    -0.008876  0.089703  0.021753 -0.222593 -0.021893 -0.168728 -0.049263
# v24     1.000000 -0.086092 -0.090944 -0.177590 -0.026083  0.034224 -0.110487
# v25    -0.086092  1.000000  0.042279  0.189765  0.115413 -0.080155  0.028993
# v26    -0.090944  0.042279  1.000000  0.141305 -0.004532  0.005695  0.028084
# v27    -0.177590  0.189765  0.141305  1.000000  0.129850  0.047768  0.108442
# v28    -0.026083  0.115413 -0.004532  0.129850  1.000000 -0.032445  0.069350
# amount  0.034224 -0.080155  0.005695  0.047768 -0.032445  1.000000  0.044921
# class  -0.110487  0.028993  0.028084  0.108442  0.069350  0.044921  1.000000
#
# [31 rows x 31 columns]

# %%
df_corr_class=fraud_df.corr()['class'].to_frame()

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_corr_class,y=df_corr_class.index,x='class')
# Out:
# <Axes: xlabel='class'>

# %%
x=fraud_df.drop(['class'],axis=1)
y=fraud_df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((662, 30), (284, 30), (662,), (284,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(max_iter=500)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
lr.score(x_train,y_train)
# Out:
# 0.945619335347432

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,recall_score,precision_score,accuracy_score,f1_score,ConfusionMatrixDisplay

# %%
precision_score(y_test,y_pred)
# Out:
# 0.9642857142857143

# %%
recall_score(y_test,y_pred)
# Out:
# 0.9375

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns 
cm = confusion_matrix(y_test, y_pred, labels=lr.classes_)
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=lr.classes_)
cmd = cmd.plot(cmap='icefire')
plt.show()

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9507042253521126
